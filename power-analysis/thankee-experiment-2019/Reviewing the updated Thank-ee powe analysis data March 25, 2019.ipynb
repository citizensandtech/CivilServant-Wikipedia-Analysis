# %%
options("scipen"=9, "digits"=4)
library(dplyr)
library(MASS)
library(ggplot2)
library(rlang)
library(tidyverse)
library(viridis)
library(fabricatr)
library(DeclareDesign)
library(blockTools)
## Installed DeclareDesign 0.13 using the following command:
# install.packages("DeclareDesign", dependencies = TRUE,
#                 repos = c("http://R.declaredesign.org", "https://cloud.r-project.org"))


library(survminer)
library(survival)
## ^^ documentation: https://cran.r-project.org/web/packages/survminer/vignettes/Informative_Survival_Plots.html

## DOCUMENTATION AT: https://cran.r-project.org/web/packages/DeclareDesign/DeclareDesign.pdf
cbPalette <- c("#999999", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7")
options(repr.plot.width=7, repr.plot.height=3.5)
sessionInfo()
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘MASS’
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ tibble  1.4.2     ✔ purrr   0.2.5
# ✔ tidyr   0.8.2     ✔ stringr 1.3.1
# ✔ readr   1.2.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ purrr::%||%()        masks rlang::%||%()
# ✖ purrr::%@%()         masks rlang::%@%()
# ✖ purrr::as_function() masks rlang::as_function()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ purrr::flatten()     masks rlang::flatten()
# ✖ purrr::flatten_chr() masks rlang::flatten_chr()
# ✖ purrr::flatten_dbl() masks rlang::flatten_dbl()
# ✖ purrr::flatten_int() masks rlang::flatten_int()
# ...

# %%
data.path <- "~/Tresors/CivilServant/projects/wikipedia-integration/gratitude-study/datasets/power_analysis"
subsample.filename <- "thankee_power_analysis_data_for_sim_treatment_20180601_200_subsamples.csv"
all.power.df <- read.csv(file.path(data.path, subsample.filename))

## non talk are non-talk
## main are only the zero namespace
## num_prev_thanks_in_90_pre_treatment ## <- received

# %%
print("num quality pre treatment")
summary(all.power.df$num_quality_pre_treatment)
print("num quality pre treatment non talk")
summary(all.power.df$num_quality_pre_treatment_non_talk)
print("num quality pre treatment main only")
summary(all.power.df$num_quality_pre_treatment_main_only)
print("num prev thanks received in 90 pre treatment")
summary(all.power.df$num_prev_thanks_in_90_pre_treatment)

print("has email")
summary(all.power.df$has_email)
# Out:
# [1] "num quality pre treatment"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    2.00    5.00    8.57    9.00   50.00
# [1] "num quality pre treatment non talk"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    2.00    4.00    7.68    8.00   50.00
# [1] "num quality pre treatment main only"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    0.00    3.00    5.62    6.00   50.00
# [1] "num prev thanks received in 90 pre treatment"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     0.0     0.0     0.0     0.9     0.0   900.0
# [1] "has email"
# False  True
#   109  6291

# %%
colnames(all.power.df)
# Out:
#  [1] "X"
#  [2] "lang"
#  [3] "user_id"
#  [4] "user_name"
#  [5] "user_registration"
#  [6] "live_edit_count"
#  [7] "first_edit"
#  [8] "last_edit"
#  [9] "active_in_90_pre_treatment"
# [10] "experience_level_pre_treatment"
# [11] "recent_edits_pre_treatment"
# [12] "num_prev_thanks_in_90_pre_treatment"
# [13] "edits_pre_treatment"
# [14] "has_email"
# [15] "num_quality_pre_treatment"
# [16] "num_quality_pre_treatment_non_talk"
# [17] "num_quality_pre_treatment_main_only"
# [18] "num_edits_90_pre_treatment"
# [19] "num_edits_90_post_treatment"
# [20] "num_labour_hours_90_pre_treatment"
# [21] "num_labour_hours_90_post_treatment"
# [22] "num_edits_90_post_treatment_week_1"
# [23] "num_edits_90_post_treatment_week_1_any"
# [24] "num_edits_90_post_treatment_week_2"
# [25] "num_edits_90_post_treatment_week_2_any"
# [26] "num_edits_90_post_treatment_week_3"
# [27] "num_edits_90_post_treatment_week_3_any"
# [28] "num_edits_90_post_treatment_week_4"
# ...
